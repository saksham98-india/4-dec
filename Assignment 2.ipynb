# %%
import pandas as pd

# %%
df_filpkart = pd.read_csv("C:/Users/SAKSHAM MITTAL/Downloads/4 dec/flipkart_com-ecommerce_sample.csv")
df_amazon = pd.read_csv("C:/Users/SAKSHAM MITTAL/Downloads/4 dec/amz_com-ecommerce_sample.csv",encoding='latin1')

# %%
df_filpkart.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df_amazon.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df_filpkart.shape
# Out:
# (20000, 15)

# %%
df_amazon.shape
# Out:
# (20000, 15)

# %%
df_filpkart.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                 78
# discounted_price             78
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %%
df_filpkart.dropna(inplace=True)

# %%
df_filpkart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14058 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  14058 non-null  object
#  1   crawl_timestamp          14058 non-null  object
#  2   product_url              14058 non-null  object
#  3   product_name             14058 non-null  object
#  4   product_category_tree    14058 non-null  object
#  5   pid                      14058 non-null  object
#  6   retail_price             14058 non-null  float64
#  7   discounted_price         14058 non-null  float64
#  8   image                    14058 non-null  object
#  9   is_FK_Advantage_product  14058 non-null  bool
#  10  description              14058 non-null  object
#  11  product_rating           14058 non-null  object
#  12  overall_rating           14058 non-null  object
#  13  brand                    14058 non-null  object
# ...

# %%
df_amazon.isnull().sum()
# Out:
# uniq_id                       0
# crawl_timestamp               0
# product_url                   0
# product_name                  0
# product_category_tree         0
# pid                           0
# retail_price                  0
# discounted_price              0
# image                         3
# is_FK_Advantage_product       0
# description                   2
# product_rating                0
# overall_rating                0
# brand                      5864
# product_specifications       14
# dtype: int64

# %%
df_amazon.dropna(inplace= True)

# %%
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14121 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  14121 non-null  object
#  1   crawl_timestamp          14121 non-null  object
#  2   product_url              14121 non-null  object
#  3   product_name             14121 non-null  object
#  4   product_category_tree    14121 non-null  object
#  5   pid                      14121 non-null  object
#  6   retail_price             14121 non-null  int64
#  7   discounted_price         14121 non-null  int64
#  8   image                    14121 non-null  object
#  9   is_FK_Advantage_product  14121 non-null  bool
#  10  description              14121 non-null  object
#  11  product_rating           14121 non-null  object
#  12  overall_rating           14121 non-null  object
#  13  brand                    14121 non-null  object
# ...

# %%
df_filpkart['uniq_id'].equals(df_amazon['uniq_id'])
# Out:
# False

# %%
df_merge = pd.merge(df_filpkart,df_amazon, on = ('uniq_id','crawl_timestamp','product_url','product_category_tree','pid','image','is_FK_Advantage_product','description','product_rating','overall_rating','product_specifications','brand'), suffixes=('_filpkart','_amazon'), validate='1:m')

# %%
df_merge
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 2      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 3      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# 4      ce5a6818f7707e2cb61fdcdbba61f5ad  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 13265  7415e1a421fb468d25a5ea56350f44be  2015-12-01 10:15:43 +0000
# 13266  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 13267  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 13268  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 13269  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df_new = df_merge.drop(columns= ('uniq_id'))
df_new = df_new.drop(columns=('crawl_timestamp'))
df_new = df_new.drop(columns= ('product_url'))
df_new = df_new.drop(columns= ('product_category_tree'))
df_new = df_new.drop(columns= ('pid'))
df_new = df_new.drop(columns= ('image'))
df_new = df_new.drop(columns= ('is_FK_Advantage_product'))
df_new = df_new.drop(columns= ('description'))
df_new = df_new.drop(columns= ('product_rating'))
df_new = df_new.drop(columns= ('overall_rating'))
df_new = df_new.drop(columns= ('product_specifications'))
df_new = df_new.drop(columns= ('brand'))
df_new
# Out:
#                          product_name_filpkart  retail_price_filpkart  \
# 0          Alisha Solid Women's Cycling Shorts                  999.0
# 1                                   AW Bellies                  999.0
# 2          Alisha Solid Women's Cycling Shorts                  699.0
# 3        Sicons All Purpose Arnica Dog Shampoo                  220.0
# 4          Alisha Solid Women's Cycling Shorts                 1199.0
# ...                                        ...                    ...
# 13265  Wallmantra Large Vinyl Stickers Sticker                  727.0
# 13266  Wallmantra Large Vinyl Stickers Sticker                 1429.0
# 13267  Elite Collection Medium Acrylic Sticker                 1299.0
# 13268  Elite Collection Medium Acrylic Sticker                 1499.0
# 13269  Elite Collection Medium Acrylic Sticker                 1499.0
#
#        discounted_price_filpkart                      product_name_amazon  \
# ...

# %%
df_new['product_name_filpkart'] = df_new['product_name_filpkart'].str.lower()
df_new['product_name_amazon'] = df_new['product_name_amazon'].str.lower()
df_new.head()
# Out:
#                    product_name_filpkart  retail_price_filpkart  \
# 0    alisha solid women's cycling shorts                  999.0
# 1                             aw bellies                  999.0
# 2    alisha solid women's cycling shorts                  699.0
# 3  sicons all purpose arnica dog shampoo                  220.0
# 4    alisha solid women's cycling shorts                 1199.0
#
#    discounted_price_filpkart                    product_name_amazon  \
# 0                      379.0    alisha solid women's cycling shorts
# 1                      499.0                             aw bellies
# 2                      267.0    alisha solid women's cycling shorts
# 3                      210.0  sicons all purpose arnica dog shampoo
# 4                      479.0    alisha solid women's cycling shorts
#
#    retail_price_amazon  discounted_price_amazon
# 0                  982                      438
# 1                  991                      551
# ...

# %%
X = str(input("Enter product name: ")).lower().strip()
print(X)
df_new.loc[df_new['product_name_filpkart'] == X]
# Out:
# Enter product name: alisha solid women's cycling shorts
# alisha solid women's cycling shorts
#                   product_name_filpkart  retail_price_filpkart  \
# 0   alisha solid women's cycling shorts                  999.0
# 2   alisha solid women's cycling shorts                  699.0
# 4   alisha solid women's cycling shorts                 1199.0
# 6   alisha solid women's cycling shorts                 1199.0
# 9   alisha solid women's cycling shorts                  999.0
# 11  alisha solid women's cycling shorts                  999.0
#
#     discounted_price_filpkart                  product_name_amazon  \
# 0                       379.0  alisha solid women's cycling shorts
# 2                       267.0  alisha solid women's cycling shorts
# 4                       479.0  alisha solid women's cycling shorts
# 6                       479.0  alisha solid women's cycling shorts
# 9                       379.0  alisha solid women's cycling shorts
# ...
